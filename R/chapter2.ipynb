# %% [markdown]
# # Applied Exercises

# %% [markdown]
# #### 1. This exercise related to the College datast, which can be found in the file College.csv. It contains a number of variables for 777 different universities and colleges in the US.

# %% [markdown]
# #### a. Use the read.csv function to read the data into R.

# %%
college = read.csv("College.csv")

# %% [markdown]
# #### b. Look at the data using the fix function. Set rownames as the name of each university or college. Remove college names from the actual dataframe.

# %%
# fix(college)

# %%
rownames(college)=college[, 1]

# %%
# fix(college)

# %%
college = college[, -1]

# %%
# fix(college)

# %% [markdown]
# #### c. i. Use the summary function to produce a numerical summary of the variables in the dataset.

# %%
summary(college)
# Out:
#  Private        Apps           Accept          Enroll       Top10perc
#  No :212   Min.   :   81   Min.   :   72   Min.   :  35   Min.   : 1.00
#  Yes:565   1st Qu.:  776   1st Qu.:  604   1st Qu.: 242   1st Qu.:15.00
#            Median : 1558   Median : 1110   Median : 434   Median :23.00
#            Mean   : 3002   Mean   : 2019   Mean   : 780   Mean   :27.56
#            3rd Qu.: 3624   3rd Qu.: 2424   3rd Qu.: 902   3rd Qu.:35.00
#            Max.   :48094   Max.   :26330   Max.   :6392   Max.   :96.00
#    Top25perc      F.Undergrad     P.Undergrad         Outstate
#  Min.   :  9.0   Min.   :  139   Min.   :    1.0   Min.   : 2340
#  1st Qu.: 41.0   1st Qu.:  992   1st Qu.:   95.0   1st Qu.: 7320
#  Median : 54.0   Median : 1707   Median :  353.0   Median : 9990
#  Mean   : 55.8   Mean   : 3700   Mean   :  855.3   Mean   :10441
#  3rd Qu.: 69.0   3rd Qu.: 4005   3rd Qu.:  967.0   3rd Qu.:12925
#  Max.   :100.0   Max.   :31643   Max.   :21836.0   Max.   :21700
# ...

# %% [markdown]
# #### c. ii. Use the pairs function to produce a scatterplot matrix of the first ten columns or variables of the data.

# %%
pairs(college[,1:10])
# Out:
# plot without title

# %% [markdown]
# #### c. iii. Use the plot( ) function to produce side-by-side boxplots of Outstate vs. Private.

# %%
attach(college)
names(college)
# Out:
#  [1] "Private"     "Apps"        "Accept"      "Enroll"      "Top10perc"
#  [6] "Top25perc"   "F.Undergrad" "P.Undergrad" "Outstate"    "Room.Board"
# [11] "Books"       "Personal"    "PhD"         "Terminal"    "S.F.Ratio"
# [16] "perc.alumni" "Expend"      "Grad.Rate"

# %%
boxplot(Outstate, Private)
# Out:
# plot without title

# %% [markdown]
# #### c. iv. Create a new qualitative variable, called Elite, by binning the Top10Perc variable. We are going to divide universities into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds %50.

# %%
Elite = rep("No", nrow(college))
Elite[Top10perc > 50] = "Yes"
Elite = as.factor(Elite)
college = data.frame(college, Elite)

# %%
summary(Elite)
# Out:
#  No Yes
# 699  78

# %%
boxplot(Outstate, Elite)
# Out:
# plot without title

# %% [markdown]
# #### c. v. Use the hist( ) function to produce some histograms with differing numbers of bins for a few of the quantitative variables.

# %%
# fix(college)

# %%
summary(college)
# Out:
#  Private        Apps           Accept          Enroll       Top10perc
#  No :212   Min.   :   81   Min.   :   72   Min.   :  35   Min.   : 1.00
#  Yes:565   1st Qu.:  776   1st Qu.:  604   1st Qu.: 242   1st Qu.:15.00
#            Median : 1558   Median : 1110   Median : 434   Median :23.00
#            Mean   : 3002   Mean   : 2019   Mean   : 780   Mean   :27.56
#            3rd Qu.: 3624   3rd Qu.: 2424   3rd Qu.: 902   3rd Qu.:35.00
#            Max.   :48094   Max.   :26330   Max.   :6392   Max.   :96.00
#    Top25perc      F.Undergrad     P.Undergrad         Outstate
#  Min.   :  9.0   Min.   :  139   Min.   :    1.0   Min.   : 2340
#  1st Qu.: 41.0   1st Qu.:  992   1st Qu.:   95.0   1st Qu.: 7320
#  Median : 54.0   Median : 1707   Median :  353.0   Median : 9990
#  Mean   : 55.8   Mean   : 3700   Mean   :  855.3   Mean   :10441
#  3rd Qu.: 69.0   3rd Qu.: 4005   3rd Qu.:  967.0   3rd Qu.:12925
#  Max.   :100.0   Max.   :31643   Max.   :21836.0   Max.   :21700
# ...

# %% [markdown]
# #### 9. This exercise involves the Auto dataset. Make sure that the missing values have been removed from the data.

# %%
auto = read.csv("Auto.csv", header=T, na.strings="?")
auto = na.omit(auto)

# %%
fix(auto)

# %% [markdown]
# #### a. Which of the predictors are quantitative, and which are qualitative?

# %% [markdown]
# The predictors "name" and "origin" are qualitative, and the remaining are quantitative.

# %% [markdown]
# #### b. What is the range of each quantitative predictor? You can answer this using the range( ) function.

# %%
names(auto)
# Out:
# [1] "mpg"          "cylinders"    "displacement" "horsepower"   "weight"
# [6] "acceleration" "year"         "origin"       "name"

# %%
attach(auto)

# %%
drops = c("name", "origin")
auto2 = auto[, !(names(auto) %in% drops)]

# %%
# fix(auto2)
nrow(auto2)
# Out:
# [1] 392

# %%
for (col in names(auto2)) {
    range = range(auto2[col])
    print(col)
    print(range)
}
# Out:
# [1] "mpg"
# [1]  9.0 46.6
# [1] "cylinders"
# [1] 3 8
# [1] "displacement"
# [1]  68 455
# [1] "horsepower"
# [1]  46 230
# [1] "weight"
# [1] 1613 5140
# [1] "acceleration"
# [1]  8.0 24.8
# [1] "year"
# [1] 70 82

# %% [markdown]
# #### c. What is the mean and standard deviation of each quantitative predictor?

# %%
sapply(auto2, function(cl) list(means=mean(cl,na.rm=TRUE), sds=sd(cl,na.rm=TRUE)))
# Out:
#       mpg      cylinders displacement horsepower weight   acceleration year
# means 23.44592 5.471939  194.412      104.4694   2977.584 15.54133     75.97959
# sds   7.805007 1.705783  104.644      38.49116   849.4026 2.758864     3.683737

# %% [markdown]
# #### d. Remove the 10th through 85th observations. What is the range, mean, and sd of each predictor that remains?

# %%
auto3 <- auto2[-c(10:85),]
nrow(auto3)
# Out:
# [1] 316

# %%
sapply(auto3, function(cl) list(means=mean(cl,na.rm=TRUE), sds=sd(cl,na.rm=TRUE)))
# Out:
#       mpg      cylinders displacement horsepower weight   acceleration year
# means 24.40443 5.373418  187.2405     100.7215   2935.972 15.7269      77.14557
# sds   7.867283 1.654179  99.67837     35.70885   811.3002 2.693721     3.106217

# %% [markdown]
# #### e. Using the fill dataset, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings.

# %%
plot(auto2)
# Out:
# plot without title

# %%
plot(horsepower, displacement, main="Horsepower vs. Displacement")
# Out:
# Plot with title “Horsepower vs. Displacement”

# %%
plot(horsepower, acceleration)
# Out:
# plot without title

# %% [markdown]
# #### 10. This exercise involves the Boston housing dataset.
#
# #### a. To begin, load in the Boston dataset. The Boston dataset is part of the MASS library in R.

# %%
library(MASS)

# %%
Boston
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio black
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3    396.90
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8    396.90
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8    392.83
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7    394.63
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7    396.90
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7    394.12
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    395.60
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    396.90
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    386.63
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    386.71
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    392.52
# ...

# %%
?Boston

# %% [markdown]
# #### b. Make some pairwise scatterplots of the predictors in this dataset. Describe your findings.

# %%
plot(Boston)
# Out:
# plot without title

# %%
attach(Boston)
plot(ptratio, crim, main="Pupil to Teacher Ratio vs. Crime Rate Per Capita")
# Out:
# Plot with title “Pupil to Teacher Ratio vs. Crime Rate Per Capita”

# %%
plot(medv, crim, main="Median Val of Owner Occupied Homes (in $1000s) vs Crime Rate.")
# Out:
# Plot with title “Median Val of Owner Occupied Homes (in $1000s) vs Crime Rate.”

# %%
plot(rm, medv, main="Avg Number of Rooms per Dwelling vs Median Hous Val")
# Out:
# Plot with title “Avg Number of Rooms per Dwelling vs Median Hous Val”

# %% [markdown]
# #### d. Are any of the predictors associated with per capita crime rate? If so, explain the relationship.

# %%
cor(Boston)
# Out:
#         crim        zn          indus       chas         nox
# crim     1.00000000 -0.20046922  0.40658341 -0.055891582  0.42097171
# zn      -0.20046922  1.00000000 -0.53382819 -0.042696719 -0.51660371
# indus    0.40658341 -0.53382819  1.00000000  0.062938027  0.76365145
# chas    -0.05589158 -0.04269672  0.06293803  1.000000000  0.09120281
# nox      0.42097171 -0.51660371  0.76365145  0.091202807  1.00000000
# rm      -0.21924670  0.31199059 -0.39167585  0.091251225 -0.30218819
# age      0.35273425 -0.56953734  0.64477851  0.086517774  0.73147010
# dis     -0.37967009  0.66440822 -0.70802699 -0.099175780 -0.76923011
# rad      0.62550515 -0.31194783  0.59512927 -0.007368241  0.61144056
# tax      0.58276431 -0.31456332  0.72076018 -0.035586518  0.66802320
# ptratio  0.28994558 -0.39167855  0.38324756 -0.121515174  0.18893268
# black   -0.38506394  0.17552032 -0.35697654  0.048788485 -0.38005064
# lstat    0.45562148 -0.41299457  0.60379972 -0.053929298  0.59087892
# ...

# %% [markdown]
# From the first row of correlation matrix above, we see the correlation between crime rate and every other predictor in the dataset. Positive correlation is denoted by a positive number (i.e. as this predictor increases, crime rate increases), negative correlation by a negative numbe (i.e. as this predictor increases, crime rate decreases). The higher the absolute value of the result, the stronger the correlation.

# %% [markdown]
# #### d. Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %%
?Boston

# %%
summary(Boston)
# Out:
#       crim                zn             indus            chas
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   Min.   :0.00000
#  1st Qu.: 0.08204   1st Qu.:  0.00   1st Qu.: 5.19   1st Qu.:0.00000
#  Median : 0.25651   Median :  0.00   Median : 9.69   Median :0.00000
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14   Mean   :0.06917
#  3rd Qu.: 3.67708   3rd Qu.: 12.50   3rd Qu.:18.10   3rd Qu.:0.00000
#  Max.   :88.97620   Max.   :100.00   Max.   :27.74   Max.   :1.00000
#       nox               rm             age              dis
#  Min.   :0.3850   Min.   :3.561   Min.   :  2.90   Min.   : 1.130
#  1st Qu.:0.4490   1st Qu.:5.886   1st Qu.: 45.02   1st Qu.: 2.100
#  Median :0.5380   Median :6.208   Median : 77.50   Median : 3.207
#  Mean   :0.5547   Mean   :6.285   Mean   : 68.57   Mean   : 3.795
#  3rd Qu.:0.6240   3rd Qu.:6.623   3rd Qu.: 94.08   3rd Qu.: 5.188
#  Max.   :0.8710   Max.   :8.780   Max.   :100.00   Max.   :12.127
# ...

# %%
print("Crime rate per capita")
cat("range:", range(crim), " mean:", mean(crim))
cat("\n")
print("Pupil-teacher ratio")
cat("range", range(ptratio), " mean:", mean(ptratio))
cat("\n")
print("Tax rates")
cat("range", range(tax), " mean:", mean(tax))
# Out:
# [1] "Crime rate per capita"
# range: 0.00632 88.9762  mean: 3.613524
# [1] "Pupil-teacher ratio"
# range 12.6 22  mean: 18.45553
# [1] "Tax rates"
# range 187 711  mean: 408.2372

# %% [markdown]
# We see from above that the max value for crime rate per capita greatly exceeds the mean, the max value for pupil-teacher ratio is comparatively close to the mean, and the max value for tax rate is comparatively high compared to the mean.

# %% [markdown]
# #### e. How many of the suburbs in this data set bound the Charles river?

# %%
s <- subset(Boston, chas == 1)

# %%
nrow(s) # number of suburbs in data set which bound the Charles river
# Out:
# [1] 35

# %% [markdown]
# #### f. What is the median pupil-teacher ratio among the towns in this dataset?

# %%
median(ptratio)
# Out:
# [1] 19.05

# %% [markdown]
# #### g. Which suburb of Boston has the lowest median value of owner-occupied homes? What are the values f the other predictors for that suburb and how do those values compare to the overall ranges for those predictors?

# %%
subset(Boston, medv == min(medv))
# Out:
#     crim    zn indus chas nox   rm    age dis    rad tax ptratio black  lstat
# 399 38.3518 0  18.1  0    0.693 5.453 100 1.4896 24  666 20.2    396.90 30.59
# 406 67.9208 0  18.1  0    0.693 5.683 100 1.4254 24  666 20.2    384.97 22.98
#     medv
# 399 5
# 406 5

# %%
summary(Boston)
# Out:
#       crim                zn             indus            chas
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   Min.   :0.00000
#  1st Qu.: 0.08204   1st Qu.:  0.00   1st Qu.: 5.19   1st Qu.:0.00000
#  Median : 0.25651   Median :  0.00   Median : 9.69   Median :0.00000
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14   Mean   :0.06917
#  3rd Qu.: 3.67708   3rd Qu.: 12.50   3rd Qu.:18.10   3rd Qu.:0.00000
#  Max.   :88.97620   Max.   :100.00   Max.   :27.74   Max.   :1.00000
#       nox               rm             age              dis
#  Min.   :0.3850   Min.   :3.561   Min.   :  2.90   Min.   : 1.130
#  1st Qu.:0.4490   1st Qu.:5.886   1st Qu.: 45.02   1st Qu.: 2.100
#  Median :0.5380   Median :6.208   Median : 77.50   Median : 3.207
#  Mean   :0.5547   Mean   :6.285   Mean   : 68.57   Mean   : 3.795
#  3rd Qu.:0.6240   3rd Qu.:6.623   3rd Qu.: 94.08   3rd Qu.: 5.188
#  Max.   :0.8710   Max.   :8.780   Max.   :100.00   Max.   :12.127
# ...

# %% [markdown]
# #### h. In this dataset, how many of the suburbs average more than rooms per dwelling? More than eight rooms per dwelling?

# %%
nrow(subset(Boston, rm >= 7))
# Out:
# [1] 64

# %%
nrow(subset(Boston, rm >= 8))
# Out:
# [1] 13
