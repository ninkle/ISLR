# %% [markdown]
# # Conceptual Exercises

# %% [markdown]
# #### 1. Using a little bit of algebra, prove that (4.2) is equivalent to (4.3). In other words, the logistic function representations and logit representation for the logistic regression model are equivalent.

# %% [markdown]
# Recall equation (4.2):
#
# $$ p(X) = \frac {e^{\beta_0 + \beta_1 X}} {1+ e^{\beta_0 + \beta_1 X}} $$
#
# and equation (4.3):
#
# $$ \frac {p(X)} {1 - p(X)} = e^{\beta_0 + \beta_1 X} $$
#
# We divide both sides of (4.2) by 1 - p(X):
#
# $$ \frac {p(X)} {1-p(X)} = \frac {\frac {e^{\beta_0 + \beta_1 X}} {1 + e^{\beta_0 + \beta_1 X}}}
#         {1 - \frac {e^{\beta_0 + \beta_1 X}} {1 + e^{\beta_0 + \beta_1 X}}} $$
#
# $$ = \frac {\frac {e^{\beta_0 + \beta_1 X}} {1 + e^{\beta_0 + \beta_1 X}}}
#         {\frac {1 + e^{\beta_0 + \beta_1 X}} {1 + e^{\beta_0 + \beta_1 X}} - \frac {e^{\beta_0 + \beta_1 X}} {1 + e^{\beta_0 + \beta_1 X}}}$$
#
# $$ = \frac {\frac {e^{\beta_0 + \beta_1 X}} {1 + e^{\beta_0 + \beta_1 X}}} {\frac {1} {1 + e^{\beta_0 + \beta_1 X}}} $$
#
# $$ = e^{\beta_0 + \beta_1 X} $$

# %% [markdown]
# #### 2. It was stated in the text that classifying an observation to the class for which (4.12) is the largest is equivalent to classifying an observation to the class for which (4.13) is largest. Prove that this is the case. In other words, under the assumption that the observations in the kth class are drawn from a N(μ, σ^2) distribution, the Bayes classifier assigns an observation to the class for which the discriminant function is minimized.

# %% [markdown]
# Recall equation 4.12:
#
# $$ p_{k}(x) = \frac {\pi \frac {1} {\sqrt{2 \pi \sigma}} exp (- \frac {1} {2 \sigma ^2} (x - \mu_{k}^2)}
# {\sum_{l=1}^{K} \pi _{l} \frac {1}{\sqrt {\pi \sigma}}exp(- \frac {1}{2 \sigma ^2 (x- \mu _{l})^2}) }$$
#
# and equation 4.13:
#
# $$ \delta _{k}(x) = x \cdot \frac {\mu_{k}} {\sigma^2} - \frac {\mu_{k}^2} {2\sigma^2}+log(\pi_{k})$$
#
# We aim to show that maximizing (4.12) is equivalent to maximizing (4.13).
#
# Recall that $\pi_{k}$ denotes the prior probability that an observation belongs to the $k^{th} class$

# %% [markdown]
# # Applied Exercises

# %% [markdown]
# #### 10. This question should be answered using the Weekly data set, which is part of the ISLR package.

# %%
library(ISLR)

# %%
weekly = Weekly

# %%
na.omit(weekly)
# Out:
#      Year Lag1   Lag2   Lag3   Lag4   Lag5   Volume    Today  Direction
# 1    1990  0.816  1.572 -3.936 -0.229 -3.484 0.1549760 -0.270 Down
# 2    1990 -0.270  0.816  1.572 -3.936 -0.229 0.1485740 -2.576 Down
# 3    1990 -2.576 -0.270  0.816  1.572 -3.936 0.1598375  3.514 Up
# 4    1990  3.514 -2.576 -0.270  0.816  1.572 0.1616300  0.712 Up
# 5    1990  0.712  3.514 -2.576 -0.270  0.816 0.1537280  1.178 Up
# 6    1990  1.178  0.712  3.514 -2.576 -0.270 0.1544440 -1.372 Down
# 7    1990 -1.372  1.178  0.712  3.514 -2.576 0.1517220  0.807 Up
# 8    1990  0.807 -1.372  1.178  0.712  3.514 0.1323100  0.041 Up
# 9    1990  0.041  0.807 -1.372  1.178  0.712 0.1439720  1.253 Up
# 10   1990  1.253  0.041  0.807 -1.372  1.178 0.1336350 -2.678 Down
# 11   1990 -2.678  1.253  0.041  0.807 -1.372 0.1490240 -1.793 Down
# 12   1990 -1.793 -2.678  1.253  0.041  0.807 0.1357900  2.820 Up
# 13   1990  2.820 -1.793 -2.678  1.253  0.041 0.1398980  4.022 Up
# ...

# %% [markdown]
# #### a. Produce some numerical and graphical summaries of the Weekly data. Do there appear to be any patterns?

# %%
summary(weekly)
# Out:
#       Year           Lag1               Lag2               Lag3
#  Min.   :1990   Min.   :-18.1950   Min.   :-18.1950   Min.   :-18.1950
#  1st Qu.:1995   1st Qu.: -1.1540   1st Qu.: -1.1540   1st Qu.: -1.1580
#  Median :2000   Median :  0.2410   Median :  0.2410   Median :  0.2410
#  Mean   :2000   Mean   :  0.1506   Mean   :  0.1511   Mean   :  0.1472
#  3rd Qu.:2005   3rd Qu.:  1.4050   3rd Qu.:  1.4090   3rd Qu.:  1.4090
#  Max.   :2010   Max.   : 12.0260   Max.   : 12.0260   Max.   : 12.0260
#       Lag4               Lag5              Volume            Today
#  Min.   :-18.1950   Min.   :-18.1950   Min.   :0.08747   Min.   :-18.1950
#  1st Qu.: -1.1580   1st Qu.: -1.1660   1st Qu.:0.33202   1st Qu.: -1.1540
#  Median :  0.2380   Median :  0.2340   Median :1.00268   Median :  0.2410
#  Mean   :  0.1458   Mean   :  0.1399   Mean   :1.57462   Mean   :  0.1499
#  3rd Qu.:  1.4090   3rd Qu.:  1.4050   3rd Qu.:2.05373   3rd Qu.:  1.4050
# ...

# %%
plot(weekly)
# Out:
# plot without title

# %%
attach(weekly)

# %%
plot(Year, Volume, main="Year vs. Volume")
# Out:
# Plot with title “Year vs. Volume”

# %%
plot(Volume)
# Out:
# plot without title

# %%
plot(Today)
# Out:
# plot without title

# %%
names(weekly)
# Out:
# [1] "Year"      "Lag1"      "Lag2"      "Lag3"      "Lag4"      "Lag5"
# [7] "Volume"    "Today"     "Direction"

# %%
cor(weekly[1:8])
# Out:
#        Year        Lag1         Lag2        Lag3        Lag4
# Year    1.00000000 -0.032289274 -0.03339001 -0.03000649 -0.031127923
# Lag1   -0.03228927  1.000000000 -0.07485305  0.05863568 -0.071273876
# Lag2   -0.03339001 -0.074853051  1.00000000 -0.07572091  0.058381535
# Lag3   -0.03000649  0.058635682 -0.07572091  1.00000000 -0.075395865
# Lag4   -0.03112792 -0.071273876  0.05838153 -0.07539587  1.000000000
# Lag5   -0.03051910 -0.008183096 -0.07249948  0.06065717 -0.075675027
# Volume  0.84194162 -0.064951313 -0.08551314 -0.06928771 -0.061074617
# Today  -0.03245989 -0.075031842  0.05916672 -0.07124364 -0.007825873
#        Lag5         Volume      Today
# Year   -0.030519101  0.84194162 -0.032459894
# Lag1   -0.008183096 -0.06495131 -0.075031842
# Lag2   -0.072499482 -0.08551314  0.059166717
# Lag3    0.060657175 -0.06928771 -0.071243639
# Lag4   -0.075675027 -0.06107462 -0.007825873
# Lag5    1.000000000 -0.05851741  0.011012698
# Volume -0.058517414  1.00000000 -0.033077783
# ...

# %% [markdown]
# #### b. Use the full data set to perform a logistic regression with Direction as the response and the Lag variables plus Volume as the predictors.

# %%
glm.fit <- glm(Direction~Lag1+Lag2+Lag3+Lag4+Lag5+Volume, data=weekly, family=binomial)
summary(glm.fit)
# Out:
# Call:
# glm(formula = Direction ~ Lag1 + Lag2 + Lag3 + Lag4 + Lag5 +
#     Volume, family = binomial, data = weekly)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.6949  -1.2565   0.9913   1.0849   1.4579
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  0.26686    0.08593   3.106   0.0019 **
# Lag1        -0.04127    0.02641  -1.563   0.1181
# Lag2         0.05844    0.02686   2.175   0.0296 *
# Lag3        -0.01606    0.02666  -0.602   0.5469
# Lag4        -0.02779    0.02646  -1.050   0.2937
# Lag5        -0.01447    0.02638  -0.549   0.5833
# Volume      -0.02274    0.03690  -0.616   0.5377
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 1496.2  on 1088  degrees of freedom
# Residual deviance: 1486.4  on 1082  degrees of freedom
# AIC: 1500.4
#
# Number of Fisher Scoring iterations: 4

# %% [markdown]
# #### c. Compute the confusion matrix and overall fraction of correct predictions. Explain what the confusion matrix is telling you about the types of mistakes made by logistic regression.

# %%
length(Direction)
# Out:
# [1] 1089

# %%
glm.probs <- predict(glm.fit, type="response")

# %%
glm.pred <- rep("Down", 1089)
glm.pred[glm.probs > 0.5] <- "Up"

# %%
table(glm.pred, Direction) # compute confusion matrix
# Out:
#         Direction
# glm.pred Down  Up
#     Down   54  48
#     Up    430 557

# %% [markdown]
# We see from the above confusion matrix that our model has a high tendency to classify a set of predictors as "Up".

# %%
correct <- (54+557)/1089 # fraction of correct predictions
correct
# Out:
# [1] 0.5610652

# %%
error.rate <- 1 - correct
error.rate
# Out:
# [1] 0.4389348

# %% [markdown]
# #### d. Now fit the logistic refression model using a training data period from 1990 to 2008, with Lag2 as the only predictor. Compute the confusion matrix and the overall fraction of corrext predictions for the held out data.

# %%
weekly2 <- weekly[Year > 1989, ]

# %%
weekly2 <- weekly2[Year < 2009, ]

# %%
weekly2
# Out:
#     Year Lag1    Lag2    Lag3    Lag4    Lag5    Volume    Today   Direction
# 1   1990  0.816   1.572  -3.936  -0.229  -3.484  0.1549760 -0.270  Down
# 2   1990 -0.270   0.816   1.572  -3.936  -0.229  0.1485740 -2.576  Down
# 3   1990 -2.576  -0.270   0.816   1.572  -3.936  0.1598375  3.514  Up
# 4   1990  3.514  -2.576  -0.270   0.816   1.572  0.1616300  0.712  Up
# 5   1990  0.712   3.514  -2.576  -0.270   0.816  0.1537280  1.178  Up
# 6   1990  1.178   0.712   3.514  -2.576  -0.270  0.1544440 -1.372  Down
# 7   1990 -1.372   1.178   0.712   3.514  -2.576  0.1517220  0.807  Up
# 8   1990  0.807  -1.372   1.178   0.712   3.514  0.1323100  0.041  Up
# 9   1990  0.041   0.807  -1.372   1.178   0.712  0.1439720  1.253  Up
# 10  1990  1.253   0.041   0.807  -1.372   1.178  0.1336350 -2.678  Down
# 11  1990 -2.678   1.253   0.041   0.807  -1.372  0.1490240 -1.793  Down
# 12  1990 -1.793  -2.678   1.253   0.041   0.807  0.1357900  2.820  Up
# ...

# %%
glm.fit2 <- glm(weekly2$Direction~weekly2$Lag2, family=binomial)
summary(glm.fit2)
# Out:
# Call:
# glm(formula = weekly2$Direction ~ weekly2$Lag2, family = binomial)
#
# Deviance Residuals:
#    Min      1Q  Median      3Q     Max
# -1.536  -1.264   1.021   1.091   1.368
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept)   0.20326    0.06428   3.162  0.00157 **
# weekly2$Lag2  0.05810    0.02870   2.024  0.04298 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 1354.7  on 984  degrees of freedom
# Residual deviance: 1350.5  on 983  degrees of freedom
# AIC: 1354.5
#
# Number of Fisher Scoring iterations: 4

# %%
length(weekly2$Direction)
# Out:
# [1] 985

# %%
glm.probs2 <- predict(glm.fit2, type="response")

# %%
glm.pred2 <- rep("Down", 985)
glm.pred2[glm.probs2 > 0.5] <- "Up"

# %%
table(glm.pred2, Direction) # compute confusion matrix
# Out:
#          Direction
# glm.pred2 Down  Up
#      Down   23  20
#      Up    418 524

# %% [markdown]
# As above, this classifier exhibits a strong bias towards an "Up" prediction.

# %%
correct <- mean(glm.pred2==weekly2$Direction) # fraction of correct predictions
correct # performs slightly worse than the classiier in c.
# Out:
# [1] 0.5553299

# %% [markdown]
# #### e. Repeat d. using LDA.

# %%
library(MASS)
lda.fit <- lda(weekly2$Direction~weekly2$Lag2, data=weekly2)

# %%
lda.fit
# Out:
# Call:
# lda(weekly2$Direction ~ weekly2$Lag2, data = weekly2)
#
# Prior probabilities of groups:
#      Down        Up
# 0.4477157 0.5522843
#
# Group means:
#      weekly2$Lag2
# Down  -0.03568254
# Up     0.26036581
#
# Coefficients of linear discriminants:
#                    LD1
# weekly2$Lag2 0.4414162
